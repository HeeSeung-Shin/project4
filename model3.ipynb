# %% [markdown]
# # YOLO5 모델 다운로드

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# %mkdir /content/yolov5/kickboard
# %cd /content/yolov5/kickboard
# !curl -L "https://universe.roboflow.com/ds/dzqjOgDhUH?key=uNV81vkhbv" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %mkdir /content/yolov5/kickboard2
# %cd /content/yolov5/kickboard2
# !curl -L "https://universe.roboflow.com/ds/tMs4DxWF2U?key=ELAupLPqDU" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %mkdir /content/yolov5/kickboard3
# %cd /content/yolov5/kickboard3
# !curl -L "https://universe.roboflow.com/ds/GhygCT9Nb7?key=EmfNHb7qLH" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %mkdir /content/yolov5/helmet
# %cd /content/yolov5/helmet
# !curl -L "https://universe.roboflow.com/ds/GsoK9ngwT5?key=c3k0hmJReu" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %mkdir /content/yolov5/helmet2
# %cd /content/yolov5/helmet2
# !curl -L "https://universe.roboflow.com/ds/x6HtfMuKYH?key=WapK5JpUJv" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %mkdir /content/yolov5/helmet3
# %cd /content/yolov5/helmet3
# !curl -L curl -L "https://universe.roboflow.com/ds/WaM7agJrsU?key=D3YnA9jZhb" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

import torch
from IPython.display import Image, clear_output
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: train/images/PartB_01821_jpg.rf.c793f2090d96443239a54c3284d0c3fa.jpg
#  extracting: train/images/PartB_01822_jpg.rf.2ec2c4fa7063e47d0d53bb2982f6cc7f.jpg
#  extracting: train/images/PartB_01823_jpg.rf.34fecdc3554b1b682cc1044dc384bdc6.jpg
#  extracting: train/images/PartB_01824_jpg.rf.6faec17c786e62871bd7f32b396f7218.jpg
#  extracting: train/images/PartB_01825_jpg.rf.7ddbf3e37fcec95325f22766729e2d5d.jpg
#  extracting: train/images/PartB_01826_jpg.rf.4c71b4758df05b8cd560df3bdac584d6.jpg
#  extracting: train/images/PartB_01827_jpg.rf.f949b0dc1ebcbe037ba6929939f264b1.jpg
#  extracting: train/images/PartB_01828_jpg.rf.b1e86b2958e0630dd25a2863bd0e300e.jpg
#  extracting: train/images/PartB_01829_jpg.rf.6fb39ecb42d76a088384628b83624f55.jpg
#  extracting: train/images/PartB_01831_jpg.rf.a3a1792fac4f310a949b0aef1861ee72.jpg
#  extracting: train/images/PartB_01832_jpg.rf.7941b56c4c4c9ea8c09a90303dc5bc1d.jpg
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # 킥보드 데이터셋 다운

# %% [markdown]
# # 학습,검증, 테스트 세트로 분리

# %%
from glob import glob
k1_train_img_list = glob('/content/yolov5/kickboard/train/images/*.jpg')
k1_test_img_list = glob('/content/yolov5/kickboard/test/images/*.jpg')
k1_val_img_list = glob('/content/yolov5/kickboard/valid/images/*.jpg')
print(len(k1_train_img_list),len(k1_test_img_list),len(k1_val_img_list))
# Out:
# 2262 0 93

# %%
from sklearn.model_selection import train_test_split

k1_val_img_list, k1_test_img_list = train_test_split(k1_val_img_list, test_size=0.5, random_state=42)
print(len(k1_train_img_list),len(k1_test_img_list),len(k1_val_img_list))
# Out:
# 2262 47 46

# %%
import yaml

with open('/content/yolov5/kickboard/train.txt','w') as f:
    f.write('\n'.join(k1_train_img_list)+'\n')

with open('/content/yolov5/kickboard/test.txt','w') as f:
    f.write('\n'.join(k1_test_img_list)+'\n')

with open('/content/yolov5/kickboard/val.txt','w') as f:
    f.write('\n'.join(k1_val_img_list)+'\n')

# %%
from glob import glob
k2_train_img_list = glob('/content/yolov5/kickboard2/train/images/*.jpg')
k2_test_img_list = glob('/content/yolov5/kickboard2/test/images/*.jpg')
k2_val_img_list = glob('/content/yolov5/kickboard2/valid/images/*.jpg')
print(len(k2_train_img_list),len(k2_test_img_list),len(k2_val_img_list))
# Out:
# 3949 193 385

# %%
import yaml

with open('/content/yolov5/kickboard2/train.txt','w') as f:
    f.write('\n'.join(k2_train_img_list)+'\n')

with open('/content/yolov5/kickboard2/test.txt','w') as f:
    f.write('\n'.join(k2_test_img_list)+'\n')

with open('/content/yolov5/kickboard2/val.txt','w') as f:
    f.write('\n'.join(k2_val_img_list)+'\n')

# %%
from glob import glob
k3_train_img_list = glob('/content/yolov5/kickboard3/train/images/*.jpg')
k3_test_img_list = glob('/content/yolov5/kickboard3/test/images/*.jpg')
k3_val_img_list = glob('/content/yolov5/kickboard3/valid/images/*.jpg')
print(len(k3_train_img_list),len(k3_test_img_list),len(k3_val_img_list))
# Out:
# 1912 116 213

# %%
import yaml

with open('/content/yolov5/kickboard3/train.txt','w') as f:
    f.write('\n'.join(k3_train_img_list)+'\n')

with open('/content/yolov5/kickboard3/test.txt','w') as f:
    f.write('\n'.join(k3_test_img_list)+'\n')

with open('/content/yolov5/kickboard3/val.txt','w') as f:
    f.write('\n'.join(k3_val_img_list)+'\n')

# %%
from glob import glob
h1_train_img_list = glob('/content/yolov5/helmet/train/images/*.jpg')
h1_test_img_list = glob('/content/yolov5/helmet/test/images/*.jpg')
h1_val_img_list = glob('/content/yolov5/helmet/valid/images/*.jpg')
print(len(h1_train_img_list),len(h1_test_img_list),len(h1_val_img_list))
# Out:
# 413 64 116

# %%
import yaml

with open('/content/yolov5/helmet/train.txt','w') as f:
    f.write('\n'.join(h1_train_img_list)+'\n')

with open('/content/yolov5/helmet/test.txt','w') as f:
    f.write('\n'.join(h1_test_img_list)+'\n')

with open('/content/yolov5/helmet/val.txt','w') as f:
    f.write('\n'.join(h1_val_img_list)+'\n')

# %%
from glob import glob
h2_train_img_list = glob('/content/yolov5/helmet2/train/images/*.jpg')
h2_test_img_list = glob('/content/yolov5/helmet2/test/images/*.jpg')
h2_val_img_list = glob('/content/yolov5/helmet2/valid/images/*.jpg')
print(len(h2_train_img_list),len(h2_test_img_list),len(h2_val_img_list))
# Out:
# 1630 233 466

# %%
import yaml

with open('/content/yolov5/helmet2/train.txt','w') as f:
    f.write('\n'.join(h2_train_img_list)+'\n')

with open('/content/yolov5/helmet2/test.txt','w') as f:
    f.write('\n'.join(h2_test_img_list)+'\n')

with open('/content/yolov5/helmet2/val.txt','w') as f:
    f.write('\n'.join(h2_val_img_list)+'\n')

# %%
from glob import glob
h3_train_img_list = glob('/content/yolov5/helmet3/train/images/*.jpg')
h3_test_img_list = glob('/content/yolov5/helmet3/test/images/*.jpg')
h3_val_img_list = glob('/content/yolov5/helmet3/valid/images/*.jpg')
print(len(h3_train_img_list),len(h3_test_img_list),len(h3_val_img_list))
# Out:
# 712 98 202

# %%
import yaml

with open('/content/yolov5/helmet3/train.txt','w') as f:
    f.write('\n'.join(h3_train_img_list)+'\n')

with open('/content/yolov5/helmet3/test.txt','w') as f:
    f.write('\n'.join(h3_test_img_list)+'\n')

with open('/content/yolov5/helmet3/val.txt','w') as f:
    f.write('\n'.join(h3_val_img_list)+'\n')

# %%
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line,cell):
    with open(line,'w') as f:
        f.write(cell.format(**globals()))

# %%
# %cat /content/yolov5/kickboard/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 2
# names: ['scooter', 'things']

# %%
# %cat /content/yolov5/kickboard2/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 4
# names: ['beam', 'dear', 'gcooter', 'others']

# %%
# %cat /content/yolov5/kickboard3/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 2
# names: ['person', 'scooter']

# %%
# %cat /content/yolov5/helmet/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 2
# names: ['Helmet', 'No Helmet']

# %%
# %cat /content/yolov5/helmet2/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 1
# names: ['head']

# %%
# %cat /content/yolov5/helmet3/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 7
# names: ['hm1', 'hm2', 'hm3', 'hm4', 'hm5', 'hm8', 'hm9']
#
# roboflow:
#   workspace: project
#   project: all3-87myx
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/project/all3-87myx/dataset/1

# %%
# 위에꺼 보고 names랑 nc 정해주기
## data yaml에다 옮겨주자

# %cd yolov5
# %%writetemplate /content/yolov5/data/combined.yaml
train: #train images 
  - kickboard/train/images
  - kickboard2/train/images
  - kickboard3/train/images
  - helmet/train/images
  - helmet2/train/images
  - helmet3/train/images
test: #test images
  - kickboard/valid/images
  - kickboard2/test/images
  - kickboard3/test/images
  - helmet/test/images
  - helmet2/test/images
  - helmet3/test/images
val: #validation images
  - kickboard/valid/images
  - kickboard2/valid/images
  - kickboard3/valid/images
  - helmet/valid/images
  - helmet2/valid/images
  - helmet3/valid/images

nc: 3
names: ['scooter','Helmet', 'No Helmet']

# %% [markdown]
# ## 라벨 수정

# %%
# 킥보드 1
from glob import glob
k1_train_label_list = glob('/content/yolov5/kickboard/train/labels/*.txt')
k1_test_label_list = glob('/content/yolov5/kickboard/test/labels/*.txt')
k1_val_label_list = glob('/content/yolov5/kickboard/valid/labels/*.txt')
print(len(k1_train_label_list),len(k1_test_label_list),len(k1_val_label_list))
# Out:
# 2262 0 93

# %%
# 킥보드 1
for glob_data in [k1_train_label_list, k1_test_label_list, k1_val_label_list]:
    for txt_path in glob_data:
        with open(txt_path, "r") as f:
            lines = f.readlines()
        with open(txt_path, "w") as f:
            for line in lines:
                if line[0] == '0':
                    f.write(line)

# %%
# 킥보드 2
from glob import glob
k2_train_label_list = glob('/content/yolov5/kickboard2/train/labels/*.txt')
k2_test_label_list = glob('/content/yolov5/kickboard2/test/labels/*.txt')
k2_val_label_list = glob('/content/yolov5/kickboard2/valid/labels/*.txt')
print(len(k2_train_label_list),len(k2_test_label_list),len(k2_val_label_list))
# Out:
# 3949 193 385

# %%
# 킥보드 2
for glob_data in [k2_train_label_list, k2_test_label_list, k2_val_label_list]:
    for txt_path in glob_data:
        with open(txt_path, "r") as f:
            lines = f.readlines()
        with open(txt_path, "w") as f:
            for line in lines:
                if line[0] in ['0', '1', '2', '3']:
                    line = line.replace(line[0],'0',1)
                    f.write(line)

# %%
# 킥보드 3
from glob import glob
k3_train_label_list = glob('/content/yolov5/kickboard3/train/labels/*.txt')
k3_test_label_list = glob('/content/yolov5/kickboard3/test/labels/*.txt')
k3_val_label_list = glob('/content/yolov5/kickboard3/valid/labels/*.txt')
print(len(k3_train_label_list),len(k3_test_label_list),len(k3_val_label_list))
# Out:
# 1912 116 213

# %%
# 킥보드 3
for glob_data in [k3_train_label_list, k3_test_label_list, k3_val_label_list]:
    for txt_path in glob_data:
        with open(txt_path, "r") as f:
            lines = f.readlines()
        with open(txt_path, "w") as f:
            for line in lines:
                if line[0] == 1:
                    line = line.replace(line[0], '0',1)
                    f.write(line)

# %%
# 헬멧1
from glob import glob
h1_train_label_list = glob('/content/yolov5/helmet/train/labels/*.txt')
h1_test_label_list = glob('/content/yolov5/helmet/test/labels/*.txt')
h1_val_label_list = glob('/content/yolov5/helmet/valid/labels/*.txt')
print(len(h1_train_label_list),len(h1_test_label_list),len(h1_val_label_list))
# Out:
# 413 64 116

# %%
# 헬멧1
for glob_data in [h1_train_label_list, h1_test_label_list, h1_val_label_list]:
    for txt_path in glob_data:
        with open(txt_path, "r") as f:
            lines = f.readlines()
        with open(txt_path, "w") as f:
            for line in lines:
                if line[0] == '0':
                    line = line.replace('0','1',1)
                elif line[0] == '1':
                    line = line.replace('1','2',1)
                f.write(line)

# %%
# 헬멧2
from glob import glob
h2_train_label_list = glob('/content/yolov5/helmet2/train/labels/*.txt')
h2_test_label_list = glob('/content/yolov5/helmet2/test/labels/*.txt')
h2_val_label_list = glob('/content/yolov5/helmet2/valid/labels/*.txt')
print(len(h2_train_label_list),len(h2_test_label_list),len(h2_val_label_list))
# Out:
# 1630 233 466

# %%
# 헬멧2
for glob_data in [h2_train_label_list, h2_test_label_list, h2_val_label_list]:
    for txt_path in glob_data:
        with open(txt_path, "r") as f:
            lines = f.readlines()
        with open(txt_path, "w") as f:
            for line in lines:
                if line[0] == '0':
                    line = line.replace('0','2',1)
                    f.write(line)

# %%
# 헬멧 3
from glob import glob
h3_train_label_list = glob('/content/yolov5/helmet3/train/labels/*.txt')
h3_test_label_list = glob('/content/yolov5/helmet3/test/labels/*.txt')
h3_val_label_list = glob('/content/yolov5/helmet3/valid/labels/*.txt')
print(len(h3_train_label_list),len(h3_test_label_list),len(h3_val_label_list))
# Out:
# 712 98 202

# %%
# 헬멧 3
for glob_data in [h3_train_label_list, h3_test_label_list, h3_val_label_list]:
    for txt_path in glob_data:
        with open(txt_path, "r") as f:
            lines = f.readlines()
        with open(txt_path, "w") as f:
            for line in lines:
                line = line.replace(line[0] ,'1',1)
                f.write(line)

# %% [markdown]
# # 모델 생성

# %%
import yaml

with open('/content/yolov5/data/combined.yaml', 'r') as stream:
    num_classes =str(yaml.safe_load(stream)['nc'])

# %cat /content/yolov5/models/yolov5x.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 1.33  # model depth multiple
# width_multiple: 1.25  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
# ...

# %%
# 학습할 모델에 맞게 변경
# %%writetemplate /content/yolov5/models/custom_yolov5x.yaml
# Parameters
nc: {num_classes}  # number of classes
depth_multiple: 1.33  # model depth multiple
width_multiple: 1.25  # layer channel multiple
anchors:
  - [10,13, 16,30, 33,23]  # P3/8
  - [30,61, 62,45, 59,119]  # P4/16
  - [116,90, 156,198, 373,326]  # P5/32

# YOLOv5 v6.0 backbone
backbone:
  # [from, number, module, args]
  [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
   [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
   [-1, 3, C3, [128]],
   [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
   [-1, 6, C3, [256]],
   [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
   [-1, 9, C3, [512]],
   [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
   [-1, 3, C3, [1024]],
   [-1, 1, SPPF, [1024, 5]],  # 9
  ]

# YOLOv5 v6.0 head
head:
  [[-1, 1, Conv, [512, 1, 1]],
   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
   [[-1, 6], 1, Concat, [1]],  # cat backbone P4
   [-1, 3, C3, [512, False]],  # 13

   [-1, 1, Conv, [256, 1, 1]],
   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
   [[-1, 4], 1, Concat, [1]],  # cat backbone P3
   [-1, 3, C3, [256, False]],  # 17 (P3/8-small)

   [-1, 1, Conv, [256, 3, 2]],
   [[-1, 14], 1, Concat, [1]],  # cat head P4
   [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)

   [-1, 1, Conv, [512, 3, 2]],
   [[-1, 10], 1, Concat, [1]],  # cat head P5
   [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)

   [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
  ]

# %%
# %cat /content/yolov5/models/custom_yolov5x.yaml
# Out:
# # Parameters
# nc: 3  # number of classes
# depth_multiple: 1.33  # model depth multiple
# width_multiple: 1.25  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
# ...

# %% [markdown]
# ### 학습(Training)
#
# * `img`: 입력 이미지 크기 정의
# * `batch`: 배치 크기 결정
# * `epochs`: 학습 기간 개수 정의
# * `data`: yaml 파일 경로
# * `cfg`: 모델 구성 지정
# * `weights`: 가중치에 대한 경로 지정
# * `name`: 결과 이름
# * `nosave`: 최종 체크포인트만 저장
# * `cache`: 빠른 학습을 위한 이미지 캐시

# %%
# %%time
# %cd /content/yolov5/
# weight는 학습이니 안준다.
# 난 pro니 epochs 두배해도 될듯??
# 학습 더해야할듯?? 성능 그리 안나왔음 100번은
# !python train.py --batch 32 --epochs 10 --data ./data/combined.yaml --cfg ./models/custom_yolov5x.yaml --weights yolov5x.pt --name kickboard_results --cache  --freeze 10
# Out:
# /content/yolov5
# train: weights=yolov5x.pt, cfg=./models/custom_yolov5x.yaml, data=./data/combined.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=kickboard_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-21-ga1b6e79 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# %%time
# %cd /content/yolov5/
# !python train.py --batch 32 --epochs 10 --data ./data/combined.yaml --cfg ./models/custom_yolov5x.yaml --weights /content/drive/MyDrive/kickboard_new/kickboard_new_epoch30/best.pt --name kickboard_results --cache  --freeze 10
# Out:
# /content/yolov5
# train: weights=/content/drive/MyDrive/kickboard_new/kickboard_new_epoch30/best.pt, cfg=./models/custom_yolov5x.yaml, data=./data/combined.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=kickboard_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# %cp runs/train/kickboard_results5/weights/best.pt /content/drive/My\ Drive/kickboard_new/kickboard_new_epoch20

# %%
# %%time
# %cd /content/yolov5/
# weight는 학습이니 안준다.
# 난 pro니 epochs 두배해도 될듯??
# 학습 더해야할듯?? 성능 그리 안나왔음 100번은
# !python train.py --batch 32 --epochs 10 --data ./data/combined.yaml --cfg ./models/custom_yolov5x.yaml --weights /content/drive/MyDrive/kickboard_new/kickboard_new_epoch20/best.pt --name kickboard_results --cache  --freeze 10
# Out:
# /content/yolov5
# train: weights=/content/drive/MyDrive/kickboard_new/kickboard_new_epoch20/best.pt, cfg=./models/custom_yolov5x.yaml, data=./data/combined.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=kickboard_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-21-ga1b6e79 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# %cp runs/train/kickboard_results6/weights/best.pt /content/drive/My\ Drive/kickboard_new/kickboard_new_epoch30

# %%
# %%time
# %cd /content/yolov5/
# weight는 학습이니 안준다.
# 난 pro니 epochs 두배해도 될듯??
# 학습 더해야할듯?? 성능 그리 안나왔음 100번은
# !python train.py --batch 32 --epochs 10 --data ./data/combined.yaml --cfg ./models/custom_yolov5x.yaml --weights /content/drive/MyDrive/kickboard_new/kickboard_new_epoch40/best.pt --name kickboard_results --cache  --freeze 10
# Out:
# /content/yolov5
# train: weights=/content/drive/MyDrive/kickboard_new/kickboard_new_epoch40/best.pt, cfg=./models/custom_yolov5x.yaml, data=./data/combined.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=kickboard_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# %cp runs/train/kickboard_results2/weights/best.pt /content/drive/My\ Drive/kickboard_new/kickboard_new_epoch40

# %%
# %%time
# %cd /content/yolov5/
# weight는 학습이니 안준다.
# 난 pro니 epochs 두배해도 될듯??
# 학습 더해야할듯?? 성능 그리 안나왔음 100번은
# !python train.py --batch 32 --epochs 10 --data ./data/combined.yaml --cfg ./models/custom_yolov5x.yaml --weights /content/drive/MyDrive/kickboard_new/kickboard_new_epoch40/best.pt --name kickboard_results --cache  --freeze 10
# Out:
# /content/yolov5
# train: weights=/content/drive/MyDrive/kickboard_new/kickboard_new_epoch40/best.pt, cfg=./models/custom_yolov5x.yaml, data=./data/combined.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=kickboard_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# %cp runs/train/kickboard_results3/weights/best.pt /content/drive/My\ Drive/kickboard_new/kickboard_new_epoch50
# %cp runs/train/kickboard_results3/results.png /content/drive/My\ Drive/kickboard_new/kickboard_new_epoch50

# %%
# %mkdir /content/drive/My\ Drive/kickboard_new/kickboard_new_epoch60

# %%
# %%time
# %cd /content/yolov5/
# weight는 학습이니 안준다.
# 난 pro니 epochs 두배해도 될듯??
# 학습 더해야할듯?? 성능 그리 안나왔음 100번은
# !python train.py --batch 32 --epochs 10 --data ./data/combined.yaml --cfg ./models/custom_yolov5x.yaml --weights /content/drive/MyDrive/kickboard_new/kickboard_new_epoch50/best.pt --name kickboard_results --cache  --freeze 10
# Out:
# /content/yolov5
# train: weights=/content/drive/MyDrive/kickboard_new/kickboard_new_epoch50/best.pt, cfg=./models/custom_yolov5x.yaml, data=./data/combined.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=kickboard_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# %cp runs/train/kickboard_results4/weights/best.pt /content/drive/My\ Drive/kickboard_new/kickboard_new_epoch60
# %cp runs/train/kickboard_results4/results.png /content/drive/My\ Drive/kickboard_new/kickboard_new_epoch60
