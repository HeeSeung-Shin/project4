# %% [markdown]
# # YOLO5 모델 다운로드

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# %mkdir /content/yolov5/helmet_val
# %cd /content/yolov5/helmet_val
# !curl -L "https://universe.roboflow.com/ds/ryDySnpenz?key=VW7c4W6pXH" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %mkdir /content/yolov5/helmet_val2
# %cd /content/yolov5/helmet_val2
# !curl -L "https://universe.roboflow.com/ds/QHkXHmwwJt?key=QATVxSLtsi" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %mkdir /content/yolov5/people_val
# %cd /content/yolov5/people_val
# !curl -L "https://universe.roboflow.com/ds/aMMl3Mrs43?key=3NfpJbtV1P" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip


import torch
from IPython.display import Image, clear_output
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: train/images/KakaoTalk_20220606_224702870_20_jpg.rf.e1e71d43df3e47e9d745113583f752ae.jpg
#  extracting: train/images/KakaoTalk_20220606_224702870_21_jpg.rf.91781004d2c1261c2ee263cfc5659246.jpg
#  extracting: train/images/KakaoTalk_20220606_224702870_21_jpg.rf.a9f15d0518ddda28bf92ba6299b85b30.jpg
#  extracting: train/images/KakaoTalk_20220606_224702870_21_jpg.rf.d6d51faf450fdb8d8b19bacd8d759979.jpg
#  extracting: train/images/KakaoTalk_20220606_224702870_22_jpg.rf.3f5af28890ad5ddc9bf62b0ec2c48872.jpg
#  extracting: train/images/KakaoTalk_20220606_224702870_22_jpg.rf.987dae97eccfa8b1b7b70ba14ae3a86c.jpg
#  extracting: train/images/KakaoTalk_20220606_224702870_22_jpg.rf.e424b0dc5be403f556add085cee44a08.jpg
#  extracting: train/images/KakaoTalk_20220606_224702870_23_jpg.rf.02579c17293f65ccf1b9580d7224708a.jpg
#  extracting: train/images/KakaoTalk_20220606_224702870_23_jpg.rf.73a24e3f821dd81619cdbb07ceb1648d.jpg
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # 킥보드 데이터셋 다운

# %%
from glob import glob
hv_train_img_list = glob('/content/yolov5/helmet_val/train/images/*.jpg')
hv_test_img_list = glob('/content/yolov5/helmet_val/test/images/*.jpg')
hv_val_img_list = glob('/content/yolov5/helmet_val/valid/images/*.jpg')
print(len(hv_train_img_list),len(hv_test_img_list),len(hv_val_img_list))
# Out:
# 720 68 34

# %%
# from sklearn.model_selection import train_test_split

# k_val_img_list, k_test_img_list = train_test_split(k_val_img_list, test_size=0.5, random_state=42)
# print(len(k_train_img_list),len(k_test_img_list),len(k_val_img_list))

# %%
import yaml

with open('/content/yolov5/helmet_val/train.txt','w') as f:
    f.write('\n'.join(hv_train_img_list)+'\n')

with open('/content/yolov5/helmet_val/test.txt','w') as f:
    f.write('\n'.join(hv_test_img_list)+'\n')

with open('/content/yolov5/helmet_val/val.txt','w') as f:
    f.write('\n'.join(hv_val_img_list)+'\n')

# %%
from glob import glob
hv2_train_img_list = glob('/content/yolov5/helmet_val2/train/images/*.jpg')
hv2_test_img_list = glob('/content/yolov5/helmet_val2/test/images/*.jpg')
hv2_val_img_list = glob('/content/yolov5/helmet_val2/valid/images/*.jpg')
print(len(hv2_train_img_list),len(hv2_test_img_list),len(hv2_val_img_list))
# Out:
# 2856 0 0

# %%
from sklearn.model_selection import train_test_split

hv2_train_img_list, hv2_test_img_list = train_test_split(hv2_train_img_list, test_size=0.1, random_state=42)
hv2_val_img_list, hv2_test_img_list = train_test_split(hv2_test_img_list, test_size=0.5, random_state=42)

print(len(hv2_train_img_list),len(hv2_test_img_list),len(hv2_val_img_list))
# Out:
# 2570 143 143

# %%
import yaml

with open('/content/yolov5/helmet_val2/train.txt','w') as f:
    f.write('\n'.join(hv2_train_img_list)+'\n')

with open('/content/yolov5/helmet_val2/test.txt','w') as f:
    f.write('\n'.join(hv2_test_img_list)+'\n')

with open('/content/yolov5/helmet_val2/val.txt','w') as f:
    f.write('\n'.join(hv2_val_img_list)+'\n')

# %%
from glob import glob
pv_train_img_list = glob('/content/yolov5/people_val/train/images/*.jpg')
pv_test_img_list = glob('/content/yolov5/people_val/test/images/*.jpg')
pv_val_img_list = glob('/content/yolov5/people_val/valid/images/*.jpg')
print(len(pv_train_img_list),len(pv_test_img_list),len(pv_val_img_list))
# Out:
# 3489 75 0

# %%
from sklearn.model_selection import train_test_split

pv_val_img_list, pv_test_img_list = train_test_split(pv_test_img_list, test_size=0.5, random_state=42)
print(len(pv_train_img_list),len(pv_test_img_list),len(pv_val_img_list))
# Out:
# 3489 38 37

# %%
import yaml

with open('/content/yolov5/people_val/train.txt','w') as f:
    f.write('\n'.join(pv_train_img_list)+'\n')

with open('/content/yolov5/people_val/test.txt','w') as f:
    f.write('\n'.join(pv_test_img_list)+'\n')

with open('/content/yolov5/people_val/val.txt','w') as f:
    f.write('\n'.join(pv_val_img_list)+'\n')

# %%
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line,cell):
    with open(line,'w') as f:
        f.write(cell.format(**globals()))

# %%
# %cat /content/yolov5/helmet_val/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 2
# names: ['kb_with_helmet', 'kb_without_helmet']
#
# roboflow:
#   workspace: new-workspace-n4nrm
#   project: kickboard-t07nm
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/new-workspace-n4nrm/kickboard-t07nm/dataset/1

# %%
# %cat /content/yolov5/helmet_val2/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 2
# names: ['helmet', 'no helmet']

# %%
# %cat /content/yolov5/people_val/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 2
# names: ['one_people', 'two_people']

# %%
# %cat /content/yolov5/mul_val/data.yaml

# %%
# 위에꺼 보고 names랑 nc 정해주기
## data yaml에다 옮겨주자

# %cd yolov5
# %%writetemplate /content/yolov5/data/combined.yaml
train: #train images 
  - helmet_val/train/images
  - helmet_val2/train/images
  - people_val/train/images
test: #test images
  - helmet_val/test/images
  - helmet_val2/train/images
  - people_val/test/images
val: #validation images
  - helmet_val/valid/images
  - helmet_val2/train/images
  - people_val/test/images

nc: 4
names: ['helmet', 'no-helmet','one', 'two']

# %% [markdown]
# ## 라벨 수정

# %%
# 헬멧
from glob import glob
pv_train_label_list = glob('/content/yolov5/people_val/train/labels/*.txt')
pv_test_label_list = glob('/content/yolov5/people_val/test/labels/*.txt')
pv_val_label_list = glob('/content/yolov5/people_val/valid/labels/*.txt')
print(len(pv_train_label_list),len(pv_test_label_list),len(pv_val_label_list))
# Out:
# 3489 75 0

# %%
# 헬멧
for glob_data in [pv_train_label_list, pv_test_label_list, pv_val_label_list]:
    for txt_path in glob_data:
        with open(txt_path, "r") as f:
            lines = f.readlines()
        with open(txt_path, "w") as f:
            for line in lines:
                if line[0] == '0':
                    line = line.replace('0','2',1)
                elif line[0] == '1':
                    line = line.replace('1','3',1)
                f.write(line)

# %% [markdown]
# # 모델 생성

# %%
import yaml

with open('/content/yolov5/data/combined.yaml', 'r') as stream:
    num_classes =str(yaml.safe_load(stream)['nc'])

# %cat /content/yolov5/models/yolov5x.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 1.33  # model depth multiple
# width_multiple: 1.25  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
# ...

# %%
# 학습할 모델에 맞게 변경
# %%writetemplate /content/yolov5/models/custom_yolov5x.yaml

# Parameters
nc: {num_classes}  # number of classes
depth_multiple: 1.33  # model depth multiple
width_multiple: 1.25  # layer channel multiple
anchors:
  - [10,13, 16,30, 33,23]  # P3/8
  - [30,61, 62,45, 59,119]  # P4/16
  - [116,90, 156,198, 373,326]  # P5/32

# YOLOv5 v6.0 backbone
backbone:
  # [from, number, module, args]
  [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
   [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
   [-1, 3, C3, [128]],
   [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
   [-1, 6, C3, [256]],
   [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
   [-1, 9, C3, [512]],
   [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
   [-1, 3, C3, [1024]],
   [-1, 1, SPPF, [1024, 5]],  # 9
  ]

# YOLOv5 v6.0 head
head:
  [[-1, 1, Conv, [512, 1, 1]],
   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
   [[-1, 6], 1, Concat, [1]],  # cat backbone P4
   [-1, 3, C3, [512, False]],  # 13

   [-1, 1, Conv, [256, 1, 1]],
   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
   [[-1, 4], 1, Concat, [1]],  # cat backbone P3
   [-1, 3, C3, [256, False]],  # 17 (P3/8-small)

   [-1, 1, Conv, [256, 3, 2]],
   [[-1, 14], 1, Concat, [1]],  # cat head P4
   [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)

   [-1, 1, Conv, [512, 3, 2]],
   [[-1, 10], 1, Concat, [1]],  # cat head P5
   [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)

   [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
  ]

# %%
# %cat /content/yolov5/models/custom_yolov5x.yaml
# Out:
# # Parameters
# nc: 4  # number of classes
# depth_multiple: 1.33  # model depth multiple
# width_multiple: 1.25  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
# ...

# %% [markdown]
# ### 학습(Training)
#
# * `img`: 입력 이미지 크기 정의
# * `batch`: 배치 크기 결정
# * `epochs`: 학습 기간 개수 정의
# * `data`: yaml 파일 경로
# * `cfg`: 모델 구성 지정
# * `weights`: 가중치에 대한 경로 지정
# * `name`: 결과 이름
# * `nosave`: 최종 체크포인트만 저장
# * `cache`: 빠른 학습을 위한 이미지 캐시

# %%
# %%time
# %cd /content/yolov5/
# weight는 학습이니 안준다.
# 난 pro니 epochs 두배해도 될듯??
# 학습 더해야할듯?? 성능 그리 안나왔음 100번은
# !python train.py --batch 32 --epochs 20 --data ./data/combined.yaml --cfg ./models/custom_yolov5x.yaml --weights yolov5x.pt --name kickboard_results --cache  --freeze 10
# Out:
# /content/yolov5
# train: weights=yolov5x.pt, cfg=./models/custom_yolov5x.yaml, data=./data/combined.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=kickboard_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# %cp runs/train/kickboard_results3/weights/best.pt /content/drive/MyDrive/last_try/epoch10

# %%
# %%time
# %cd /content/yolov5/
# weight는 학습이니 안준다.
# 난 pro니 epochs 두배해도 될듯??
# 학습 더해야할듯?? 성능 그리 안나왔음 100번은
# !python train.py --batch 32 --epochs 20 --data ./data/combined.yaml --cfg ./models/custom_yolov5x.yaml --weights /content/drive/MyDrive/last_try/epoch10/best.pt --name kickboard_results --cache  --freeze 10
# Out:
# /content/yolov5
# train: weights=/content/drive/MyDrive/last_try/epoch10/best.pt, cfg=./models/custom_yolov5x.yaml, data=./data/combined.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=kickboard_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# %cp runs/train/kickboard_results4/weights/best.pt /content/drive/MyDrive/last_try/epoch20

# %%
# %%time
# %cd /content/yolov5/
# weight는 학습이니 안준다.
# 난 pro니 epochs 두배해도 될듯??
# 학습 더해야할듯?? 성능 그리 안나왔음 100번은
# !python train.py --batch 32 --epochs 20 --data ./data/combined.yaml --cfg ./models/custom_yolov5x.yaml --weights /content/drive/MyDrive/last_try/epoch20/best.pt --name kickboard_results --cache  --freeze 10
# Out:
# /content/yolov5
# train: weights=/content/drive/MyDrive/last_try/epoch20/best.pt, cfg=./models/custom_yolov5x.yaml, data=./data/combined.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=kickboard_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# %cp runs/train/kickboard_results5/weights/best.pt /content/drive/MyDrive/last_try/epoch30
